# %% [markdown]
# Install and Import Dependencies

# %%
#import dependenices
import pandas as pd
import matplotlib.pyplot as plt  
import numpy as np

# %%
#Import dataset 
from ucimlrepo import fetch_ucirepo

dataset = fetch_ucirepo(id=222)

# %%
dataset
# Out:
# {'data': {'ids': None,
#   'features':        age           job   marital  education default  balance housing loan  \
#   0       58    management   married   tertiary      no     2143     yes   no
#   1       44    technician    single  secondary      no       29     yes   no
#   2       33  entrepreneur   married  secondary      no        2     yes  yes
#   3       47   blue-collar   married        NaN      no     1506     yes   no
#   4       33           NaN    single        NaN      no        1      no   no
#   ...    ...           ...       ...        ...     ...      ...     ...  ...
#   45206   51    technician   married   tertiary      no      825      no   no
#   45207   71       retired  divorced    primary      no     1729      no   no
#   45208   72       retired   married  secondary      no     5715      no   no
#   45209   57   blue-collar   married  secondary      no      668      no   no
#   45210   37  entrepreneur   married  secondary      no     2971      no   no
# ...

# %%
dataset.data
# Out:
# {'ids': None,
#  'features':        age           job   marital  education default  balance housing loan  \
#  0       58    management   married   tertiary      no     2143     yes   no
#  1       44    technician    single  secondary      no       29     yes   no
#  2       33  entrepreneur   married  secondary      no        2     yes  yes
#  3       47   blue-collar   married        NaN      no     1506     yes   no
#  4       33           NaN    single        NaN      no        1      no   no
#  ...    ...           ...       ...        ...     ...      ...     ...  ...
#  45206   51    technician   married   tertiary      no      825      no   no
#  45207   71       retired  divorced    primary      no     1729      no   no
#  45208   72       retired   married  secondary      no     5715      no   no
#  45209   57   blue-collar   married  secondary      no      668      no   no
#  45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
#View dataset
dataset.data.features
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married        NaN      no     1506     yes   no
# 4       33           NaN    single        NaN      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
dataset.data.targets
# Out:
#          y
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
# ...    ...
# 45206  yes
# 45207  yes
# 45208  yes
# 45209   no
# 45210   no
#
# [45211 rows x 1 columns]

# %%
dataset.metadata
# Out:
# {'uci_id': 222,
#  'name': 'Bank Marketing',
#  'repository_url': 'https://archive.ics.uci.edu/dataset/222/bank+marketing',
#  'data_url': 'https://archive.ics.uci.edu/static/public/222/data.csv',
#  'abstract': 'The data is related with direct marketing campaigns (phone calls) of a Portuguese banking institution. The classification goal is to predict if the client will subscribe a term deposit (variable y).',
#  'area': 'Business',
#  'tasks': ['Classification'],
#  'characteristics': ['Multivariate'],
#  'num_instances': 45211,
#  'num_features': 16,
#  'feature_types': ['Categorical', 'Integer'],
#  'demographics': ['Age', 'Occupation', 'Marital Status', 'Education Level'],
#  'target_col': ['y'],
#  'index_col': None,
#  'has_missing_values': 'yes',
#  'missing_values_symbol': 'NaN',
#  'year_of_dataset_creation': 2014,
#  'last_updated': 'Fri Aug 18 2023',
#  'dataset_doi': '10.24432/C5K306',
#  'creators': ['S. Moro', 'P. Rita', 'P. Cortez'],
#  'intro_paper': {'ID': 277,
# ...

# %%
dataset.variables
# Out:
#            name     role         type      demographic  \
# 0           age  Feature      Integer              Age
# 1           job  Feature  Categorical       Occupation
# 2       marital  Feature  Categorical   Marital Status
# 3     education  Feature  Categorical  Education Level
# 4       default  Feature       Binary             None
# 5       balance  Feature      Integer             None
# 6       housing  Feature       Binary             None
# 7          loan  Feature       Binary             None
# 8       contact  Feature  Categorical             None
# 9   day_of_week  Feature         Date             None
# 10        month  Feature         Date             None
# 11     duration  Feature      Integer             None
# 12     campaign  Feature      Integer             None
# 13        pdays  Feature      Integer             None
# 14     previous  Feature      Integer             None
# 15     poutcome  Feature  Categorical             None
# ...

# %%
#Try make the dataets in pandas
X = dataset.data.features
y = dataset.data.targets

df2 = pd.concat([X,y],axis=1)
df2
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married        NaN      no     1506     yes   no
# 4       33           NaN    single        NaN      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
#Load using pandas
df = pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\ML_dir\Projects\bank_market\bank+marketing\bank\bank-full.csv" , sep=";")

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df2.isna().sum()
# Out:
# age                0
# job              288
# marital            0
# education       1857
# default            0
# balance            0
# housing            0
# loan               0
# contact        13020
# day_of_week        0
# month              0
# duration           0
# campaign           0
# pdays              0
# previous           0
# poutcome       36959
# y                  0
# dtype: int64

# %%
df2.describe()
# Out:
#                 age        balance   day_of_week      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
df2
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married        NaN      no     1506     yes   no
# 4       33           NaN    single        NaN      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df2.shape
# Out:
# (45211, 17)

# %%
df2.isna().sum()
# Out:
# age                0
# job              288
# marital            0
# education       1857
# default            0
# balance            0
# housing            0
# loan               0
# contact        13020
# day_of_week        0
# month              0
# duration           0
# campaign           0
# pdays              0
# previous           0
# poutcome       36959
# y                  0
# dtype: int64

# %%
#Drop columns with none
df2.drop(["poutcome","contact"] , axis=1 , inplace=True)
df2
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married        NaN      no     1506     yes   no
# 4       33           NaN    single        NaN      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
dataset.variables
# Out:
#            name     role         type      demographic  \
# 0           age  Feature      Integer              Age
# 1           job  Feature  Categorical       Occupation
# 2       marital  Feature  Categorical   Marital Status
# 3     education  Feature  Categorical  Education Level
# 4       default  Feature       Binary             None
# 5       balance  Feature      Integer             None
# 6       housing  Feature       Binary             None
# 7          loan  Feature       Binary             None
# 8       contact  Feature  Categorical             None
# 9   day_of_week  Feature         Date             None
# 10        month  Feature         Date             None
# 11     duration  Feature      Integer             None
# 12     campaign  Feature      Integer             None
# 13        pdays  Feature      Integer             None
# 14     previous  Feature      Integer             None
# 15     poutcome  Feature  Categorical             None
# ...

# %%
df2['age'].value_counts()
# Out:
# age
# 32    2085
# 31    1996
# 33    1972
# 34    1930
# 35    1894
#       ...
# 95       2
# 93       2
# 92       2
# 88       2
# 94       1
# Name: count, Length: 77, dtype: int64

# %%
df2.groupby('age').size()
# Out:
# age
# 18     12
# 19     35
# 20     50
# 21     79
# 22    129
#      ...
# 90      2
# 92      2
# 93      2
# 94      1
# 95      2
# Length: 77, dtype: int64

# %%
#Group ages by yes or no
sub_df = df2[['age','y']]
sub_df
# Out:
#        age    y
# 0       58   no
# 1       44   no
# 2       33   no
# 3       47   no
# 4       33   no
# ...    ...  ...
# 45206   51  yes
# 45207   71  yes
# 45208   72  yes
# 45209   57   no
# 45210   37   no
#
# [45211 rows x 2 columns]

# %% [markdown]
# Visualize Data

# %%
#Plot Age against target
x_data = df2.age
y_data = df2.y

plt.scatter(x_data,y_data)
plt.show()

# %%
df2
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married        NaN      no     1506     yes   no
# 4       33           NaN    single        NaN      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df2.insert(loc=3,column = "education_label ",value= le.fit_transform(df2.education))
df2
# Out:
#        age           job   marital  education_label   education default  \
# 0       58    management   married                 2   tertiary      no
# 1       44    technician    single                 1  secondary      no
# 2       33  entrepreneur   married                 1  secondary      no
# 3       47   blue-collar   married                 3        NaN      no
# 4       33           NaN    single                 3        NaN      no
# ...    ...           ...       ...               ...        ...     ...
# 45206   51    technician   married                 2   tertiary      no
# 45207   71       retired  divorced                 0    primary      no
# 45208   72       retired   married                 1  secondary      no
# 45209   57   blue-collar   married                 1  secondary      no
# 45210   37  entrepreneur   married                 1  secondary      no
#
#        balance housing loan  day_of_week month  duration  campaign  pdays  \
# ...

# %%
df2.dropna(subset=["education"],inplace=True)
df2
# Out:
#        age           job   marital  education_label   education default  \
# 0       58    management   married                 2   tertiary      no
# 1       44    technician    single                 1  secondary      no
# 2       33  entrepreneur   married                 1  secondary      no
# 5       35    management   married                 2   tertiary      no
# 6       28    management    single                 2   tertiary      no
# ...    ...           ...       ...               ...        ...     ...
# 45206   51    technician   married                 2   tertiary      no
# 45207   71       retired  divorced                 0    primary      no
# 45208   72       retired   married                 1  secondary      no
# 45209   57   blue-collar   married                 1  secondary      no
# 45210   37  entrepreneur   married                 1  secondary      no
#
#        balance housing loan  day_of_week month  duration  campaign  pdays  \
# ...

# %%
df2.isna().sum()
# Out:
# age                   0
# job                 161
# marital               0
# education_label       0
# education             0
# default               0
# balance               0
# housing               0
# loan                  0
# day_of_week           0
# month                 0
# duration              0
# campaign              0
# pdays                 0
# previous              0
# y                     0
# dtype: int64

# %%
df2.dropna(subset=["job"],inplace=True)
df2
# Out:
#        age           job   marital  education_label   education default  \
# 0       58    management   married                 2   tertiary      no
# 1       44    technician    single                 1  secondary      no
# 2       33  entrepreneur   married                 1  secondary      no
# 5       35    management   married                 2   tertiary      no
# 6       28    management    single                 2   tertiary      no
# ...    ...           ...       ...               ...        ...     ...
# 45206   51    technician   married                 2   tertiary      no
# 45207   71       retired  divorced                 0    primary      no
# 45208   72       retired   married                 1  secondary      no
# 45209   57   blue-collar   married                 1  secondary      no
# 45210   37  entrepreneur   married                 1  secondary      no
#
#        balance housing loan  day_of_week month  duration  campaign  pdays  \
# ...

# %%
df2.isna().sum()
# Out:
# age                 0
# job                 0
# marital             0
# education_label     0
# education           0
# default             0
# balance             0
# housing             0
# loan                0
# day_of_week         0
# month               0
# duration            0
# campaign            0
# pdays               0
# previous            0
# y                   0
# dtype: int64

# %%
df2.insert(loc=1,column = "job_label ",value= le.fit_transform(df2.job))
df2.insert(loc=2,column = "marital_label ",value= le.fit_transform(df2.marital))
df2.insert(loc=5,column = "default_label ",value= le.fit_transform(df2.default))
df2.insert(loc=7,column = "housing_label ",value= le.fit_transform(df2.housing))
df2.insert(loc=8,column = "loan_label ",value= le.fit_transform(df2.loan))
df2.insert(loc=10,column = "month_label ",value= le.fit_transform(df2.month))

# %%
df2
# Out:
#        age  job_label   marital_label            job   marital  \
# 0       58           4               1    management   married
# 1       44           9               2    technician    single
# 2       33           2               1  entrepreneur   married
# 5       35           4               1    management   married
# 6       28           4               2    management    single
# ...    ...         ...             ...           ...       ...
# 45206   51           9               1    technician   married
# 45207   71           5               0       retired  divorced
# 45208   72           5               1       retired   married
# 45209   57           1               1   blue-collar   married
# 45210   37           2               1  entrepreneur   married
#
#        default_label   education_label   housing_label   loan_label   \
# 0                   0                 2               1            0
# ...

# %%
df2.drop(["job","marital","education","housing","loan","month","default"],axis = "columns",inplace=True)
df2
# Out:
#        age  job_label   marital_label   default_label   education_label   \
# 0       58           4               1               0                 2
# 1       44           9               2               0                 1
# 2       33           2               1               0                 1
# 5       35           4               1               0                 2
# 6       28           4               2               0                 2
# ...    ...         ...             ...             ...               ...
# 45206   51           9               1               0                 2
# 45207   71           5               0               0                 0
# 45208   72           5               1               0                 1
# 45209   57           1               1               0                 1
# 45210   37           2               1               0                 1
#
#        housing_label   loan_label   month_label   balance  day_of_week  \
# ...

# %%
df2.insert(loc=14,column = "y_label ",value= le.fit_transform(df2.y))
df2.drop(['y','duration'],axis=1,inplace=True)
df2
# Out:
#        age  job_label   marital_label   default_label   education_label   \
# 0       58           4               1               0                 2
# 1       44           9               2               0                 1
# 2       33           2               1               0                 1
# 5       35           4               1               0                 2
# 6       28           4               2               0                 2
# ...    ...         ...             ...             ...               ...
# 45206   51           9               1               0                 2
# 45207   71           5               0               0                 0
# 45208   72           5               1               0                 1
# 45209   57           1               1               0                 1
# 45210   37           2               1               0                 1
#
#        housing_label   loan_label   month_label   balance  day_of_week  \
# ...
